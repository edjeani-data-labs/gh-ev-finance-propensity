# %% [markdown]
# <p align="center">
#   <h1 style="text-align: center;">🔍📊 EV Financing Propensity Model - Ghana 🇬🇭🚗⚡️</h1>
# </p>
#
#
# ### 📘 Notebook 1: Data Ingestion, Initial Cleaning, and Exploratory Data Analysis (EDA)
#
# This notebook initiates the EV Financing Propensity Model project by focusing on the following key steps:
#
# * 🔧 1. Problem Definition and Business Context
# * 📥 2. Loading the Raw AHIES 2022–2023 Dataset
# * 🧹 3. Initial Cleaning and Feature Selection
# * 💾 4. Save the Initially Cleaned Dataset
# * 📊 5. Basic Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 1. Project Context
#
# ### 1.1 Problem Statement
# We aim to build a propensity model to identify Ghanaian households or individuals who are good targets for an electric vehicle (EV) financing loan. The core task is a supervised binary classification problem: predicting whether a household/individual is a good prospect for an EV financing loan (label = 1) or not (label = 0). Since the actual EV loan uptake label is not present in the AHIES dataset, we will need to simulate this target variable later in the project based on plausible socioeconomic features. The model will help estimate the likelihood of seeking or qualifying for an EV loan based on features like income, transport spending, urban/rural status, etc.
#
#
# ### 1.2 Business Case
# Electric mobility is an emerging sector in Ghana. A data-driven propensity model offers significant benefits to financial institutions:
# * **Targeted Marketing:** Efficiently prioritize customers most likely to adopt EV loans, increasing marketing ROI.
# * **Product Expansion:** Identify early adopters and tailor EV financing products, especially given the current low EV penetration due to high upfront costs.
# * **Risk Management:** Profile likely EV customers to better assess credit risk, potentially identifying stable, higher-income households.
# * **Competitive Advantage:** Proactively capture market share in the growing green mobility sector.
# This model aims to turn household survey data into actionable insights for financial product targeting, aligning with Ghana’s sustainability goals.

# %% [markdown]
# ## 2. Setup and Data Loading

# %% [markdown]
# ### 2.1 Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# Optional: settings to display more rows/columns if needed later
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', 100)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ### 2.2 Load Raw AHIES Dataset
#
# The following code attempts to load the AHIES dataset. It tries different encodings as survey data can sometimes have encoding issues.
# **Note:** Ensure your raw data file `AHIES2022Q1_2023Q3_SEC01234_202402.csv` is placed in the `../data/01_raw/` directory.

# %%
# Define file paths using os.path.join for better compatibility
raw_data_directory = os.path.join("..", "data", "01_raw") # More robust path
raw_file_name = "AHIES2022Q1_2023Q3_SEC01234_202402.csv" # Your specified file name
raw_file_path = os.path.join(raw_data_directory, raw_file_name)

print(f"Raw file path: {raw_file_path}")
# Out:
# Raw file path: ../data/01_raw/AHIES2022Q1_2023Q3_SEC01234_202402.csv

# %%
df_raw = None # Initialize df_raw

try:
    df_raw = pd.read_csv(raw_file_path, encoding="ISO-8859-1", low_memory=False)
    print(f"✅ File '{raw_file_name}' loaded successfully with ISO-8859-1 encoding from '{raw_file_path}'.")
except UnicodeDecodeError:
    try:
        df_raw = pd.read_csv(raw_file_path, encoding="windows-1252", low_memory=False)
        print(f"✅ File '{raw_file_name}' loaded successfully with windows-1252 encoding from '{raw_file_path}'.")
    except Exception as e:
        print(f"❌ Error loading file '{raw_file_name}' with windows-1252 encoding: {e}")
except FileNotFoundError:
    print(f"❌ Error: The file was not found at '{raw_file_path}'.")
    print("Please ensure the file exists in the specified directory and the name is correct.")
except Exception as e:
    print(f"❌ An unexpected error occurred while loading the file: {e}")
# Out:
# ✅ File 'AHIES2022Q1_2023Q3_SEC01234_202402.csv' loaded successfully with ISO-8859-1 encoding from '../data/01_raw/AHIES2022Q1_2023Q3_SEC01234_202402.csv'.

# %% [markdown]
# ### 2.3 Initial Inspection of Raw Data
#
# Let's take a quick look at the raw loaded data before selecting columns.

# %%
if df_raw is not None and not df_raw.empty:
    print("--- Raw Data: First 5 Rows ---")
    print(df_raw.head())
    print("\n" + "="*50 + "\n")

    print("--- Raw Data: Shape (rows, columns) ---")
    print(df_raw.shape)
    print("\n" + "="*50 + "\n")

    print("--- Raw Data: Info (dtypes, non-null counts) ---")
    df_raw.info(verbose=True, show_counts=True)
    print("\n" + "="*50 + "\n")
else:
    print("Raw dataframe `df_raw` is not loaded or is empty. Cannot perform inspection.")
# Out:
# --- Raw Data: First 5 Rows ---
#      hhid quarter  cluster  HholdID  personid   s1aq1  \
# 0  500109  2023Q1        1        9         2  Female
# 1  300109  2022Q3        1        9         3    Male
# 2  600114  2023Q2        1       14         1    Male
# 3  600102  2023Q2        1        2         4    Male
# 4  300114  2022Q3        1       14         3  Female
#
#                                    s1aq2  s1aq4y  s1aq4m  \
# 0  Spouse (Wife/Husband/Living together)      43     NaN
# 1                   Child (Son/Daughter)      21     NaN
# 2                                   Head      39     NaN
# 3                   Child (Son/Daughter)       3     0.0
# 4                   Child (Son/Daughter)       3     1.0
#
#                              s1aq5  ...   region        BMI pop_weight  \
# 0  Married (Customary/Traditional)  ...  WESTERN        NaN  923.53058
# 1                    Never married  ...  WESTERN  20.672762  863.96033
# 2  Married (Customary/Traditional)  ...  WESTERN        NaN  933.66388
# 3                              NaN  ...  WESTERN        NaN  933.66388
# 4                              NaN  ...  WESTERN        NaN  863.96033
#
#    hh_weight worked  wagework nowork     econact availreason  urbrur
# 0  1126.7158    1.0       NaN    NaN    Employed         NaN  Urbanb
# 1  1016.0422    NaN       NaN    1.0  Not active         NaN  Urbanb
# 2  1113.8646    1.0       1.0    NaN    Employed         NaN  Urbanb
# 3  1113.8646    NaN       NaN    NaN         NaN         NaN  Urbanb
# 4  1016.0422    NaN       NaN    NaN         NaN         NaN  Urbanb
#
# [5 rows x 607 columns]
#
# ==================================================
#
# --- Raw Data: Shape (rows, columns) ---
# (356437, 607)
#
# ==================================================
#
# --- Raw Data: Info (dtypes, non-null counts) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356437 entries, 0 to 356436
# Data columns (total 607 columns):
#  #    Column         Non-Null Count   Dtype
# ---   ------         --------------   -----
#  0    hhid           356437 non-null  int64
#  1    quarter        356437 non-null  object
#  2    cluster        356437 non-null  int64
#  3    HholdID        356437 non-null  int64
#  4    personid       356437 non-null  int64
#  5    s1aq1          356437 non-null  object
#  6    s1aq2          356437 non-null  object
#  7    s1aq4y         356437 non-null  int64
#  8    s1aq4m         45005 non-null   float64
#  9    s1aq5          242003 non-null  object
#  10   s1aq6          356437 non-null  object
#  11   s1aq6o         920 non-null     object
#  12   s1aq7          356437 non-null  object
#  13   s1aq8          2648 non-null    object
#  14   s1aq9a         353634 non-null  object
#  15   s1aq9ao        0 non-null       float64
#  16   s1aq9b         353627 non-null  object
#  17   s1aq9bo        0 non-null       float64
#  18   s1aq2x         114715 non-null  object
#  19   s1aq5x         81203 non-null   object
#  20   s1bq1          356437 non-null  object
#  21   s1bq2a         98706 non-null   object
#  22   s1bq2o         0 non-null       float64
#  23   s1bq2b         98724 non-null   object
#  24   s1bq3          257986 non-null  object
#  25   s1bq4          108080 non-null  float64
#  26   s1bq5a         108080 non-null  object
#  27   s1bq5b         108080 non-null  object
#  28   s1bq6          108080 non-null  float64
#  29   s1bq7          108080 non-null  object
#  30   s1bq7o         610 non-null     object
#  31   s2aq1          331495 non-null  object
#  32   s2aq2          80762 non-null   object
#  33   s2aq2o         0 non-null       float64
#  34   s2aq3          330887 non-null  object
#  35   s2aq3o         240 non-null     object
#  36   s2aq4          286553 non-null  float64
#  37   s2aq4o         0 non-null       float64
#  38   s2aq5          286975 non-null  object
#  39   s2aq6          155091 non-null  object
#  40   s2aq7          153954 non-null  object
#  41   s2aq8a         154696 non-null  object
#  42   s2aq8ao        139 non-null     object
#  43   s2aq8b         156842 non-null  object
#  44   s2aq8bo        505 non-null     object
#  45   s2aq9a         154231 non-null  float64
#  46   s2aq9b         150312 non-null  float64
#  47   s2aq10         133115 non-null  object
#  48   s2aq11a1       193 non-null     float64
#  49   s2aq11a2       9063 non-null    float64
#  50   s2aq11a3       560 non-null     float64
#  51   s2aq11a4       610 non-null     float64
#  52   s2aq11a5       883 non-null     float64
#  53   s2aq11a6       197 non-null     float64
#  54   s2aq11a7       7831 non-null    float64
#  55   s2aq11a8       20 non-null      float64
#  56   s2aq11a9       214 non-null     float64
#  57   s2aq11a10      11231 non-null   float64
#  58   s2aq11a11      22578 non-null   float64
#  59   s2aq11a12      9717 non-null    float64
#  60   s2aq11a13      3242 non-null    float64
#  61   s2aq11a14      51766 non-null   float64
#  62   s2aq11a15      2667 non-null    float64
#  63   s2aq11a16      20551 non-null   float64
#  64   s2aq11a17      412 non-null     float64
#  65   s2aq11a18      4083 non-null    float64
#  66   s2aq11a19      324 non-null     float64
#  67   s2aq11a20      7104 non-null    float64
#  68   s2aq11a21      945 non-null     float64
#  69   s2aq11a22      215 non-null     float64
#  70   s2aq11a23      946 non-null     float64
#  71   s2aq11a24      517 non-null     float64
#  72   s2aq11a25      719 non-null     float64
#  73   s2aq11a26      2158 non-null    float64
#  74   s2aq11a27      317 non-null     float64
#  75   s2aq11a28      37 non-null      float64
#  76   s2aq11a26o     2147 non-null    object
#  77   s2aq11a27o     324 non-null     object
#  78   s2aq11a28o     37 non-null      object
#  79   s2aq11a29      150565 non-null  float64
#  80   s2aq12         259531 non-null  object
#  81   s2aq12o        193 non-null     object
#  82   s2aq13         265989 non-null  object
#  83   s2aq13o        13 non-null      object
#  84   s2aq14         1012 non-null    float64
#  85   s2aq15         200336 non-null  object
#  86   s2aq15a        226 non-null     object
#  87   s2aq15b        10 non-null      object
#  88   s2aq15c        9 non-null       object
#  89   s2aq15d        127 non-null     object
#  90   s2aq15e        7 non-null       object
#  91   s2aq15f        48 non-null      object
#  92   s2aq15g        12 non-null      object
#  93   s2aq15h        10 non-null      object
#  94   s2aq15i        21 non-null      object
#  95   s2aq15j        760 non-null     object
#  96   s2aq15k        623 non-null     object
#  97   s2aq15l        55 non-null      object
#  98   s2aq15z        317252 non-null  object
#  99   s2aq15o        51 non-null      object
#  100  s2aq16         1802 non-null    float64
#  101  s2aq7n         39061 non-null   object
#  102  s2aq10_02      2 non-null       float64
#  103  s2aq10_22      1 non-null       float64
#  104  s2aq10_29      59 non-null      float64
#  105  s2aq10_30      38077 non-null   float64
#  106  s2bq1          212632 non-null  object
#  107  s2bq2a         47156 non-null   float64
#  108  s2bq2b         18796 non-null   float64
#  109  s2bq3a         49832 non-null   object
#  110  s2bq3b         49919 non-null   object
#  111  s3aq1          356437 non-null  object
#  112  s3aq2          45908 non-null   float64
#  113  s3aq3          45910 non-null   object
#  114  s3aq3a         0 non-null       float64
#  115  s3aq4          28303 non-null   float64
#  116  s3aq4o         0 non-null       float64
#  117  s3aq5          310312 non-null  object
#  118  s3aq6          27082 non-null   object
#  119  s3aq6o         52 non-null      object
#  120  s3aq7          27082 non-null   object
#  121  s3aq7o         56 non-null      object
#  122  s3aq8m         27082 non-null   object
#  123  s3aq8a         25789 non-null   object
#  124  s3aq8b         27082 non-null   object
#  125  s3aq8o         172 non-null     object
#  126  s3aq9          19420 non-null   float64
#  127  s3aq10         19416 non-null   float64
#  128  s3aq11         19416 non-null   float64
#  129  s3aq12         19414 non-null   float64
#  130  s3aq13         19420 non-null   float64
#  131  s3aq14         19416 non-null   float64
#  132  s3aq15         19413 non-null   float64
#  133  s3aq16         19420 non-null   object
#  134  s3aq17         2135 non-null    float64
#  135  s3aq18         2135 non-null    float64
#  136  s3aq19         300553 non-null  object
#  137  s3aq20         24244 non-null   float64
#  138  s3aq21         170106 non-null  float64
#  139  s3aq22a        275396 non-null  object
#  140  s3aq22b        1074 non-null    float64
#  141  s3aq23         306280 non-null  object
#  142  s3aq23o        323 non-null     object
#  143  s3aq23hhid     320485 non-null  float64
#  144  s3bq1          356437 non-null  object
#  145  s3bq2          298486 non-null  object
#  146  s3bq3          343649 non-null  float64
#  147  s3bq3o         865 non-null     object
#  148  s3bq4          344103 non-null  float64
#  149  s3bq4o         878 non-null     object
#  150  s3bq5          321952 non-null  object
#  151  s3cq1          311853 non-null  object
#  152  s3cq2          311921 non-null  object
#  153  s3cq3          311921 non-null  object
#  154  s3cq4          311921 non-null  object
#  155  s3cq5          311921 non-null  object
#  156  s3cq6          311921 non-null  object
#  157  s4aq6o         0 non-null       float64
#  158  s4aq1          311657 non-null  object
#  159  s4aq2          26402 non-null   float64
#  160  s4aq3a         26385 non-null   float64
#  161  s4aq3b         26160 non-null   float64
#  162  s4aq3c         25141 non-null   float64
#  163  s4aq3d         23488 non-null   float64
#  164  s4aq3e         21484 non-null   float64
#  165  s4aq3f         10164 non-null   float64
#  166  s4aq3g         3122 non-null    float64
#  167  s4aq4          292258 non-null  object
#  168  s4aq5          799 non-null     float64
#  169  s4aq6a         799 non-null     float64
#  170  s4aq6b         767 non-null     float64
#  171  s4aq6c         727 non-null     float64
#  172  s4aq6d         651 non-null     float64
#  173  s4aq6e         587 non-null     float64
#  174  s4aq6f         359 non-null     float64
#  175  s4aq6g         151 non-null     float64
#  176  s4aq7          291650 non-null  object
#  177  s4aq8          50215 non-null   float64
#  178  s4aq9a         50212 non-null   float64
#  179  s4aq9b         48158 non-null   float64
#  180  s4aq9c         45102 non-null   float64
#  181  s4aq9d         40055 non-null   float64
#  182  s4aq9e         33003 non-null   float64
#  183  s4aq9f         18326 non-null   float64
#  184  s4aq9g         4639 non-null    float64
#  185  s4aq10         50215 non-null   object
#  186  s4aq11         257655 non-null  object
#  187  s4aq12         29168 non-null   float64
#  188  s4aq13a        29166 non-null   float64
#  189  s4aq13b        28337 non-null   float64
#  190  s4aq13c        26521 non-null   float64
#  191  s4aq13d        24164 non-null   float64
#  192  s4aq13e        21540 non-null   float64
#  193  s4aq13f        15531 non-null   float64
#  194  s4aq13g        6630 non-null    float64
#  195  s4aq14         29168 non-null   object
#  196  s4aq15         237196 non-null  object
#  197  s4aq16         17275 non-null   float64
#  198  s4aq17a        17252 non-null   float64
#  199  s4aq17b        15366 non-null   float64
#  200  s4aq17c        12632 non-null   float64
#  201  s4aq17d        10581 non-null   float64
#  202  s4aq17e        8289 non-null    float64
#  203  s4aq17f        4455 non-null    float64
#  204  s4aq17g        1486 non-null    float64
#  205  s4aq18         17273 non-null   object
#  206  s4aq19         224646 non-null  object
#  207  s4aq20         940 non-null     float64
#  208  s4aq21a        940 non-null     float64
#  209  s4aq21b        877 non-null     float64
#  210  s4aq21c        770 non-null     float64
#  211  s4aq21d        648 non-null     float64
#  212  s4aq21e        522 non-null     float64
#  213  s4aq21f        302 non-null     float64
#  214  s4aq21g        106 non-null     float64
#  215  s4aq22         224022 non-null  object
#  216  s4aq23         8371 non-null    float64
#  217  s4aq24a        8370 non-null    float64
#  218  s4aq24b        8275 non-null    float64
#  219  s4aq24c        8119 non-null    float64
#  220  s4aq24d        7840 non-null    float64
#  221  s4aq24e        7350 non-null    float64
#  222  s4aq24f        4057 non-null    float64
#  223  s4aq24g        409 non-null     float64
#  224  s4aq25         178376 non-null  object
#  225  s4aq26         772 non-null     float64
#  226  s4aq27a        769 non-null     float64
#  227  s4aq27b        685 non-null     float64
#  228  s4aq27c        577 non-null     float64
#  229  s4aq27d        477 non-null     float64
#  230  s4aq27e        375 non-null     float64
#  231  s4aq27f        214 non-null     float64
#  232  s4aq27g        109 non-null     float64
#  233  s4aq28         311546 non-null  object
#  234  s4aq29         176575 non-null  object
#  235  s4aq29a        173991 non-null  object
#  236  s4aq30         173294 non-null  object
#  237  s4aq31         14057 non-null   object
#  238  s4aq32         159237 non-null  object
#  239  s4aq33         4231 non-null    object
#  240  s4aq34         155006 non-null  object
#  241  s4aq35         155884 non-null  object
#  242  s4aq36         151276 non-null  object
#  243  s4aq37         150400 non-null  object
#  244  s4aq38         177563 non-null  object
#  245  s4aq39         22887 non-null   object
#  246  s4aq39a        1809 non-null    object
#  247  s4aq40a        158178 non-null  object
#  248  s4aq40a1       155166 non-null  object
#  249  s4aq40a2       155151 non-null  float64
#  250  s4aq40a3       154848 non-null  float64
#  251  s4aq41a        158135 non-null  object
#  252  s4aq41a1       160269 non-null  object
#  253  s4aq41a2       156695 non-null  float64
#  254  s4aq41a3       156439 non-null  float64
#  255  s4aq42         158113 non-null  object
#  256  s4aq43         156471 non-null  float64
#  257  s4aq43m        156422 non-null  float64
#  258  s4aq44         156551 non-null  object
#  259  s4aq44a        1470 non-null    object
#  260  s4aq45         156562 non-null  object
#  261  s4aq46         152480 non-null  object
#  262  s4aq46a        373 non-null     object
#  263  s4aq47         26955 non-null   object
#  264  s4aq48         26668 non-null   object
#  265  s4aq49         26667 non-null   object
#  266  s4aq50         26666 non-null   object
#  267  s4aq51         26666 non-null   object
#  268  s4aq52         9391 non-null    object
#  269  s4aq52b        1205 non-null    object
#  270  s4aq52c        3791 non-null    object
#  271  s4aq52d        114 non-null     object
#  272  s4aq52e        15 non-null      object
#  273  s4aq52o        7 non-null       object
#  274  s4aq52a        40 non-null      object
#  275  s4aq53         26666 non-null   object
#  276  s4aq54         26662 non-null   object
#  277  s4aq54a        566 non-null     object
#  278  s4aq55a        26640 non-null   float64
#  279  s4aq55b        26648 non-null   object
#  280  s4aq56         26651 non-null   object
#  281  s4aq57a        3148 non-null    float64
#  282  s4aq57b        3150 non-null    object
#  283  s4aq58         26650 non-null   object
#  284  s4aq59a        1240 non-null    float64
#  285  s4aq59b        1242 non-null    object
#  286  s4aq60         5320 non-null    float64
#  287  s4bq1          150623 non-null  float64
#  288  s4bq2a         9729 non-null    object
#  289  s4bq2a1        9750 non-null    object
#  290  s4bq2a2        9749 non-null    float64
#  291  s4bq2a3        9749 non-null    float64
#  292  s4bq3a         9740 non-null    object
#  293  s4bq3a1        9750 non-null    object
#  294  s4bq3a2        9749 non-null    float64
#  295  s4bq3a3        9749 non-null    float64
#  296  s4bq4          9749 non-null    float64
#  297  s4bq5a         9742 non-null    float64
#  298  s4bq5b         7995 non-null    float64
#  299  s4bq5c         5565 non-null    float64
#  300  s4bq5d         3748 non-null    float64
#  301  s4bq5e         2812 non-null    float64
#  302  s4bq5f         1792 non-null    float64
#  303  s4bq5g         1067 non-null    float64
#  304  s4bq6          9748 non-null    object
#  305  s4bq7          9749 non-null    object
#  306  s4bq7a         47 non-null      object
#  307  s4bq8          896 non-null     object
#  308  s4bq8a         27 non-null      object
#  309  s4bq9          896 non-null     float64
#  310  s4bq9a         896 non-null     object
#  311  s4bq10         896 non-null     object
#  312  s4bq11a        86 non-null      float64
#  313  s4bq11b        86 non-null      object
#  314  s4bq12         748 non-null     object
#  315  s4bq13         896 non-null     object
#  316  s4bq14         896 non-null     object
#  317  s4bq15         896 non-null     object
#  318  s4bq16         51 non-null      object
#  319  s4bq16a        1 non-null       object
#  320  s4bq16b        10 non-null      object
#  321  s4bq16c        29 non-null      object
#  322  s4bq16d        0 non-null       float64
#  323  s4bq16e        0 non-null       float64
#  324  s4bq16_other   0 non-null       float64
#  325  s4bq17         896 non-null     object
#  326  s4bq18         9748 non-null    object
#  327  s4bq18a        166 non-null     object
#  328  s4bq19         9748 non-null    object
#  329  s4cq1          137799 non-null  float64
#  330  s4cq2          144377 non-null  object
#  331  s4cq3          99327 non-null   object
#  332  s4cq4          99327 non-null   object
#  333  s4cq5          43297 non-null   float64
#  334  s4cq6          135881 non-null  object
#  335  s4cq7          34135 non-null   object
#  336  s4cq8          3075 non-null    object
#  337  s4cq8o         56 non-null      object
#  338  s4cq9          2828 non-null    object
#  339  s4cq9a         28 non-null      object
#  340  s4cq10         3075 non-null    object
#  341  s4dq1          216238 non-null  object
#  342  s4dq2          131341 non-null  object
#  343  s4dq2o         165 non-null     object
#  344  s4dq3a         8192 non-null    object
#  345  s4dq3a1        11809 non-null   object
#  346  s4dq3a2        11807 non-null   float64
#  347  s4dq3a3        6622 non-null    float64
#  348  s4dq4a         8189 non-null    object
#  349  s4dq4a1        67381 non-null   object
#  350  s4dq4a2        67381 non-null   float64
#  351  s4dq4a3        6619 non-null    float64
#  352  s4dq5          11806 non-null   object
#  353  s4dq5a         31 non-null      object
#  354  s4dq6          11807 non-null   object
#  355  s4dq7          11807 non-null   object
#  356  s4eq1          88744 non-null   object
#  357  s4eq2          19072 non-null   object
#  358  s4eq3          15252 non-null   object
#  359  s4eq3o         234 non-null     object
#  360  s4eq4          2990 non-null    object
#  361  s4eq4o         29 non-null      object
#  362  s4eq5          2987 non-null    object
#  363  s4eq6          2985 non-null    object
#  364  s4eq6o         1 non-null       float64
#  365  s4eq7          2985 non-null    object
#  366  s4eq8a         2238 non-null    object
#  367  s4eq8a1        2151 non-null    object
#  368  s4eq8a2        1315 non-null    float64
#  369  s4eq8a3        1312 non-null    float64
#  370  s4eq9          2602 non-null    float64
#  371  s4eq9a         1177 non-null    object
#  372  s4eq10         67086 non-null   object
#  373  s4eq10o        1705 non-null    object
#  374  s4eq11         45872 non-null   object
#  375  s4eq11o        530 non-null     object
#  376  s4eq12         66826 non-null   object
#  377  s4eq13         520 non-null     object
#  378  s4eq13o        0 non-null       float64
#  379  s4eq14         66818 non-null   object
#  380  s4fq1          128207 non-null  object
#  381  s4fq2a         21534 non-null   float64
#  382  s4fq2b         21530 non-null   float64
#  383  s4fq2c         21570 non-null   object
#  384  s4fq2co        0 non-null       float64
#  385  s4fq3a         48068 non-null   float64
#  386  s4fq3b         48041 non-null   float64
#  387  s4fq3c         48156 non-null   object
#  388  s4fq3co        6374 non-null    object
#  389  s4fq4          58069 non-null   float64
#  390  s4gq1a         86956 non-null   object
#  391  s4gq1b         86951 non-null   object
#  392  s4gq1c         86949 non-null   object
#  393  s4gq1d         86949 non-null   object
#  394  s4gq1e         86947 non-null   object
#  395  s4gq1f         86946 non-null   object
#  396  s4gq1g         86946 non-null   object
#  397  s4gq1h         86943 non-null   object
#  398  s4gq1i         86945 non-null   object
#  399  s4gq1j         86943 non-null   object
#  400  s4gq1k         86943 non-null   object
#  401  s4gq1l         86941 non-null   object
#  402  s4gq1m         86940 non-null   object
#  403  s4gq1mo        102 non-null     object
#  404  s4gq2          83795 non-null   object
#  405  s4gq3          253 non-null     object
#  406  s4gq3o         39 non-null      object
#  407  s4gq4a         3624 non-null    object
#  408  s4gq4a1        3617 non-null    object
#  409  s4gq4a2        3617 non-null    float64
#  410  s4gq4a3        3617 non-null    float64
#  411  s4gq5          83439 non-null   object
#  412  s4gq6          43191 non-null   object
#  413  s4gq6o         1338 non-null    object
#  414  s4gq7a         83436 non-null   object
#  415  s4gq7b         83436 non-null   object
#  416  s4gq7c         83436 non-null   object
#  417  s4gq7d         83433 non-null   object
#  418  s4gq7e         83433 non-null   object
#  419  s4gq7f         83433 non-null   object
#  420  s4gq7g         83433 non-null   object
#  421  s4gq7h         83433 non-null   object
#  422  s4gq7i         83433 non-null   object
#  423  s4gq7j         83433 non-null   object
#  424  s4gq7k         83433 non-null   object
#  425  s4gq7l         83433 non-null   object
#  426  s4gq7m         83433 non-null   object
#  427  s4gq7n         83431 non-null   object
#  428  s4gq7o         83431 non-null   object
#  429  s4gq7oo        20 non-null      object
#  430  s4gq8a         83431 non-null   object
#  431  s4gq8b         83431 non-null   object
#  432  s4gq8c         83430 non-null   object
#  433  s4gq8d         83430 non-null   object
#  434  s4gq8e         83430 non-null   object
#  435  s4gq8eo        5 non-null       object
#  436  s4gq9a         83429 non-null   object
#  437  s4gq9b         83429 non-null   object
#  438  s4gq9c         83429 non-null   object
#  439  s4gq9d         83429 non-null   object
#  440  s4gq9e         83428 non-null   object
#  441  s4gq9f         83428 non-null   object
#  442  s4gq9g         83428 non-null   object
#  443  s4gq9h         83428 non-null   object
#  444  s4gq9i         83428 non-null   object
#  445  s4gq9j         83428 non-null   object
#  446  s4gq9k         83428 non-null   object
#  447  s4gq9l         83428 non-null   object
#  448  s4gq9m         83428 non-null   object
#  449  s4gq9n         83427 non-null   object
#  450  s4gq9o         83427 non-null   object
#  451  s4gq9oo        24 non-null      object
#  452  s4gq10a        86920 non-null   object
#  453  s4gq10b        86920 non-null   object
#  454  s4gq10c        86920 non-null   object
#  455  s4gq10d        86920 non-null   object
#  456  s4gq10e        86920 non-null   object
#  457  s4gq10f        86920 non-null   object
#  458  s4gq10g        86920 non-null   object
#  459  s4gq10h        86920 non-null   object
#  460  s4gq10i        86920 non-null   object
#  461  s4gq10j        86920 non-null   object
#  462  s4gq10k        86920 non-null   object
#  463  s4gq10l        86920 non-null   object
#  464  s4gq10m        86920 non-null   object
#  465  s4gq10n        86920 non-null   object
#  466  s4gq10no       31 non-null      object
#  467  s4gq11         86452 non-null   object
#  468  s4gq11o        32 non-null      object
#  469  s4gq12a        2334 non-null    object
#  470  s4gq12b        1093 non-null    object
#  471  s4gq12c        637 non-null     object
#  472  s4gq12d        346 non-null     object
#  473  s4gq12e        320 non-null     object
#  474  s4gq12f        1346 non-null    object
#  475  s4gq12g        32 non-null      object
#  476  s4gq13a        86916 non-null   object
#  477  s4gq13b        86916 non-null   object
#  478  s4gq13c        86916 non-null   object
#  479  s4gq13d        86916 non-null   object
#  480  s4gq13e        86916 non-null   object
#  481  s4gq13eo       84 non-null      object
#  482  s4gq14         86916 non-null   object
#  483  s4aq60x        18873 non-null   float64
#  484  s4bq16_others  0 non-null       float64
#  485  s4hq1aa        11348 non-null   float64
#  486  s4hq1ab        8434 non-null    float64
#  487  s4aq52ox       8 non-null       object
#  488  s4cq9o         2 non-null       object
#  489  s4dq5o         8 non-null       object
#  490  s4hq11a        15268 non-null   object
#  491  s4hq1ac        8232 non-null    float64
#  492  s4hq1ad        3416 non-null    float64
#  493  s4hq1ae        11434 non-null   float64
#  494  s4hq1af        4240 non-null    float64
#  495  s4hq11b        4175 non-null    object
#  496  s4hq2          15268 non-null   object
#  497  s4hq12a        14730 non-null   float64
#  498  s4hq12b        2894 non-null    float64
#  499  s4hq12c        2029 non-null    float64
#  500  s4hq2d         2878 non-null    float64
#  501  s4hq2e         3514 non-null    float64
#  502  s4hq2f         1386 non-null    float64
#  503  s4hq2g         889 non-null     float64
#  504  s4hq2h         1384 non-null    float64
#  505  s4hq2i         1256 non-null    float64
#  506  s4hq2j         4271 non-null    float64
#  507  s4hq2k         4014 non-null    float64
#  508  s4hq2z         52 non-null      float64
#  509  s4hq2o         52 non-null      object
#  510  s4hq3          15268 non-null   object
#  511  s4hq3a         3070 non-null    float64
#  512  s4hq3b         14319 non-null   float64
#  513  s4hq3c         3534 non-null    float64
#  514  s4hq3d         1785 non-null    float64
#  515  s4hq3e         2150 non-null    float64
#  516  s4hq3f         2128 non-null    float64
#  517  s4hq3g         8534 non-null    float64
#  518  s4hq3h         541 non-null     float64
#  519  s4hq3i         1941 non-null    float64
#  520  s4hq3j         1216 non-null    float64
#  521  s4hq3z         15 non-null      float64
#  522  s4hq3_other    15 non-null      object
#  523  s4hq13a        3070 non-null    object
#  524  s4hq13b        14319 non-null   object
#  525  s4hq13c        3534 non-null    object
#  526  s4hq13d        1785 non-null    object
#  527  s4hq13e        2150 non-null    object
#  528  s4hq13f        2128 non-null    object
#  529  s4hq13g        8534 non-null    object
#  530  s4hq13h        541 non-null     object
#  531  s4hq13i        1941 non-null    object
#  532  s4hq13j        1216 non-null    object
#  533  s4hq13z        15 non-null      float64
#  534  s4hq4          15268 non-null   object
#  535  s4hq4a         8902 non-null    float64
#  536  s4hq4b         7612 non-null    float64
#  537  s4hq4c         5745 non-null    float64
#  538  s4hq5          8902 non-null    object
#  539  s4hq6          3904 non-null    object
#  540  s4hq6o         1 non-null       object
#  541  s4hq7          3103 non-null    object
#  542  s4hq7o         0 non-null       float64
#  543  s4hq8          15268 non-null   object
#  544  s4hq9          15268 non-null   object
#  545  s4hq9a         2609 non-null    float64
#  546  s4hq9b         13920 non-null   float64
#  547  s4hq9c         3544 non-null    float64
#  548  s4hq9d         1783 non-null    float64
#  549  s4hq9e         2041 non-null    float64
#  550  s4hq9f         2000 non-null    float64
#  551  s4hq9g         8034 non-null    float64
#  552  s4hq9h         403 non-null     float64
#  553  s4hq9z         50 non-null      float64
#  554  s4hq9o         49 non-null      object
#  555  s4hq10a        1520 non-null    object
#  556  s4hq10aa       1128 non-null    float64
#  557  s4hq10ab       377 non-null     float64
#  558  s4hq10ac       136 non-null     float64
#  559  s4hq10b        386 non-null     object
#  560  s4hq11a0       15267 non-null   object
#  561  s4hq11a1       15269 non-null   object
#  562  s4hq11a2       15269 non-null   float64
#  563  s4hq11a3       15267 non-null   float64
#  564  s4hq11b0       15267 non-null   object
#  565  s4hq11b1       15269 non-null   object
#  566  s4hq11b2       15269 non-null   float64
#  567  s4hq11b3       15267 non-null   float64
#  568  s4hq11c0       15266 non-null   object
#  569  s4hq11c1       15269 non-null   object
#  570  s4hq11c2       15269 non-null   float64
#  571  s4hq11c3       15267 non-null   float64
#  572  s4hq12a0       15267 non-null   object
#  573  s4hq12a1       15269 non-null   object
#  574  s4hq12a2       15269 non-null   float64
#  575  s4hq12a3       15267 non-null   float64
#  576  s4hq12b0       15266 non-null   object
#  577  s4hq12b1       15269 non-null   object
#  578  s4hq12b2       15269 non-null   float64
#  579  s4hq12b3       15267 non-null   float64
#  580  s4hq12c0       15267 non-null   object
#  581  s4hq12c1       15269 non-null   object
#  582  s4hq12c2       15269 non-null   float64
#  583  s4hq12c3       15267 non-null   float64
#  584  s4hq13d0       15267 non-null   object
#  585  s4hq13d1       15269 non-null   object
#  586  s4hq13d2       15269 non-null   float64
#  587  s4hq13d3       15267 non-null   float64
#  588  s4hq13e0       15266 non-null   object
#  589  s4hq13e1       15268 non-null   object
#  590  s4hq13e2       15268 non-null   float64
#  591  s4hq13e3       15267 non-null   float64
#  592  s4hq13f0       15264 non-null   object
#  593  s4hq13f1       15268 non-null   object
#  594  s4hq13f2       15268 non-null   float64
#  595  s4hq13f3       15267 non-null   float64
#  596  s4pid4h        29332 non-null   object
#  597  region         356437 non-null  object
#  598  BMI            110139 non-null  float64
#  599  pop_weight     356437 non-null  float64
#  600  hh_weight      356437 non-null  float64
#  601  worked         157058 non-null  float64
#  602  wagework       28991 non-null   float64
#  603  nowork         150364 non-null  float64
#  604  econact        311661 non-null  object
#  605  availreason    4 non-null       object
#  606  urbrur         356437 non-null  object
# dtypes: float64(251), int64(5), object(351)
# memory usage: 1.6+ GB
#
# ==================================================

# %% [markdown]
# ## 3. Column Selection and Renaming for EV Propensity Model
#
# Based on the project goals, we will extract a subset of columns relevant to understanding socioeconomic status, demographics, income, and expenditure patterns that might influence EV adoption. We will also rename them to be more intuitive.

# %%
# Dictionary mapping original column names to new, more descriptive names
columns_to_extract_and_rename = {
    "hhid": "household_id",
    "personid": "person_id",
    "region": "region",
    "urbrur": "urban_rural",

    # Demographics
    "s1aq1": "sex",
    "s1aq4y": "age",
    "s1aq5": "marital_status",

    # Education
    "s2aq3": "highest_education_level",
    "s2aq4": "grade_completed",
    "s2aq6": "still_in_school",

    # Income - Note: These are individual level. Aggregation to household level might be needed later.
    "s4aq55a": "primary_job_income_monthly", # Assuming monthly based on typical survey questions
    "s4bq9": "secondary_job_income_monthly", # Assuming monthly
    # "s4eq9": "expected_minimum_wage", # This might be less about actual income

    # Expenditure - Note: These are specific educational/medical expenses.
    # We'll need to look for broader transport expenditure later or use these as proxies if needed.
    "s2aq11a2": "tuition_fee_paid_last_12m",
    "s2aq11a15": "transportation_cost_to_school_last_12m",
    "s2aq11a16": "school_food_cost_last_12m",
    "s3aq21": "total_medical_expense_last_12m",

    # Employment
    "s4aq1": "worked_last_7_days", # Likely employment status indicator
    # "s4aq2": "total_work_days", # May need context if this is per week/month
    # The daily work hours might be too granular for initial model, but good to have.
    # "s4aq3a": "work_hours_day_1",
    # "s4aq3b": "work_hours_day_2",
    # "s4aq3c": "work_hours_day_3",
    # "s4aq3d": "work_hours_day_4",
    # "s4aq3e": "work_hours_day_5",
    # "s4aq3f": "work_hours_day_6",
    # "s4aq3g": "work_hours_day_7",

    # Migration (Potentially useful for stability/lifestyle)
    # "s1bq1": "born_in_this_town",
    # "s1bq2a": "born_in_another_region", # This might be 'region_of_birth'
    # "s1bq5a": "previous_residence_type",
    # "s1bq6": "years_in_previous_location",
}

# Filter out columns that might not exist in df_raw to prevent KeyErrors
existing_columns_to_extract = {
    original_col: new_col
    for original_col, new_col in columns_to_extract_and_rename.items()
    if original_col in df_raw.columns
}

missing_from_raw = set(columns_to_extract_and_rename.keys()) - set(existing_columns_to_extract.keys())
if missing_from_raw:
    print(f"⚠️ Warning: The following specified columns were NOT found in the raw dataset and will be skipped:")
    for col in missing_from_raw:
        print(f"  - {col}")

df_selected = None # Initialize

if df_raw is not None and not df_raw.empty:
    if not existing_columns_to_extract:
        print("❌ Error: None of the specified columns for extraction exist in the loaded dataframe.")
        print("Please check your `columns_to_extract_and_rename` dictionary against the actual columns in the raw data.")
    else:
        df_selected = df_raw[list(existing_columns_to_extract.keys())].copy() # Use .copy() to avoid SettingWithCopyWarning
        df_selected.rename(columns=existing_columns_to_extract, inplace=True)
        print(f"✅ Columns extracted and renamed. New dataframe `df_selected` created.")
else:
    print("Raw dataframe `df_raw` is not loaded or is empty. Cannot select columns.")
# Out:
# ✅ Columns extracted and renamed. New dataframe `df_selected` created.

# %% [markdown]
# ## 4. Save Initially Cleaned (Selected) Dataset
#
# We will save this subset of data with renamed columns to the `02_intermediate` directory for further processing in subsequent notebooks.

# %%
intermediate_data_directory = os.path.join("..", "data", "02_intermediate") # More robust path
cleaned_file_name = "ahies_selected_for_ev_propensity.csv" # More descriptive name
cleaned_file_path = os.path.join(intermediate_data_directory, cleaned_file_name)

if df_selected is not None and not df_selected.empty:
    try:
        # Create the intermediate directory if it doesn't exist
        # import os # Already imported at the top
        os.makedirs(intermediate_data_directory, exist_ok=True)

        df_selected.to_csv(cleaned_file_path, index=False)
        print(f"✅ Selected and renamed dataset saved to '{cleaned_file_path}'")
    except Exception as e:
        print(f"❌ Error saving the cleaned dataset: {e}")
else:
    print("Selected dataframe `df_selected` is not created or is empty. Cannot save.")
# Out:
# ✅ Selected and renamed dataset saved to '../data/02_intermediate/ahies_selected_for_ev_propensity.csv'

# %% [markdown]
# ## 5. Next Steps
#
# * **Data Cleaning:** Dive deeper into cleaning the `df_selected` DataFrame. This will involve:
#     * Handling missing values (imputation or removal).
#     * Correcting data types if necessary.
#     * Addressing any outliers or erroneous values.
#     * Transforming variables (e.g., decoding categorical variables from numbers to meaningful labels based on the data dictionary).
# * **Exploratory Data Analysis (EDA):** Perform detailed EDA on the cleaned dataset to understand distributions, relationships, and gather insights that will inform feature engineering and modeling.
# * **Feature Engineering:** Create new relevant features.
# * **Label Simulation:** Develop and apply the logic to create our target variable.
